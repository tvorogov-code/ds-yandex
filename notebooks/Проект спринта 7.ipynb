# %% [markdown]
# <div style="border:solid green 3px; padding: 20px">
#
# <b>Привет, Андрей!</b>
#
# Меня зовут Сороколетов Илья и я буду проверять твой проект.
#
# Предлагаю общаться на «**ты**», но если тебе будет комфортнее общаться на «**вы**», то сообщи об этом в комментариях)
#
#
# Для твоего удобства, я буду выделять свои комментарии следующим образом:
#
# <div class="alert alert-danger">
# <b>❌ Комментарий ревьюера v1:</b> Самые важные замечания. Они указывают на ключевые моменты, которые влияют на конечный результат проекта. </div>
#
# <div class="alert alert-warning">
# <b>⚠️ Комментарий ревьюера v1:</b> Советы или замечания, которые помогут сделать твою работу лучше, но необязательны к выполнению.
#
# </div>
#
# <div class="alert alert-success">
# <b>✔️ Комментарий ревьюера v1:</b> Так я выделяю все остальные комментарии.</div>
#
#
# Пометками <b>v1-v2-v3-...</b> я буду отмечать версию проверки. Так ты сможешь быстро найти мои новые комментарии.
#
# Давай работать над проектом в диалоге: если ты что-то меняешь в проекте по моим рекомендациям — пиши об этом. Выбери для своих комментариев какой-то заметный цвет, так мне будет легче отследить изменения, например вот так:
#
# <div class="alert alert-info">
# <b>Комментарий студента:</b>
# <br>
# </div>
#
# <b>Пожалуйста, не перемещай, не изменяй и не удаляй мои комментарии.</b> Если ты оставляешь свои комментарии, то делай это под моими, чтобы сообщения были расположены в хронологическом порядке. Всё это поможет выполнить повторную проверку твоего проекта быстрее.
#
# Перед отправкой работы я рекомендую нажимать Kernel -> Restart & Run All. Это перезапустит ядро и по очереди выполнит все ячейки. Так ты сможешь проверить, что всё работает корректно. Кнопка Kernel находится в панели сверху
#
# Обязательно задавай вопросы если они возникнут, а я перехожу к проверке)
#
# P.S. На всякий случай, я оставлю пустой шаблон для твоих комментариев ниже. Кликни два раза на мой комментарий, скопируй последние четыре строчки кода и вставляй их в пустую ячейку там, где ты хочешь оставить комментарий. Не забудь только перед этим сменить тип ячейки на Markdown. Быстро это можно сделать так: кликнуть на ячейку - нажать ESC - нажать M.
#
#
# <div class="alert alert-info">
# <b>Комментарий студента:</b>
# <br>Удали этот текст и вместо него напиши свой комментарий 🙂
# </div>

# %% [markdown]
# # Проект спринта 7
# - Автор: Андрей Творогов
# - Дата: 26.01.2026

# %% [markdown]
# ## Цели и задачи проекта
# Цель проекта - представить исследовательский анализ открытых данных по заведениям общественного питания г. Москвы с целью выбора оптимального места для открытия нового заведения.
#
#
# Задачи, которые необходимо выполнить для достижения цели:
# 1. Предобработка данных:
# - изучение структуры данных, проверка наличия пропусков и дубликатов, соответствия типов данных типам столбцов в представленных датасетах;
# - приведение названия столбцов к единому виду (snake case), типов столбцов к соответствию с типом их содержимого;
# - оценка количества пропусков и дубликатов в данных;
# - изучение пропусков и дубликатов, определение их типов и исправление данных там, где это возможно;
# 2. Исследовательский анализ данных:
# - изучение категорий заведений в соотношении с их расположением, принадлежностью к сетям общественного питания, количеством посадочных мест;
# - исследование рейтингов заведений, их распределение и корреляцию с другими параметрами заведений;
# - определение топ-15 популярных сетей в Москве по количеству заведений;
# - сравнение среднего чека в заведениях в зависимости от района.

# %% [markdown]
# ### Описание данных
#
# Файл `/datasets/rest_info.csv` содержит информацию о заведениях общественного питания:
#
# - `name` — название заведения;
# - `address` — адрес заведения;
# - `district` — административный район, в котором находится заведение, например Центральный административный округ;
# - `category` — категория заведения, например «кафе», «пиццерия» или «кофейня»;
# - `hours` — информация о днях и часах работы;
# - `rating` — рейтинг заведения по оценкам пользователей в Яндекс Картах (высшая оценка — `5.0`);
# - `chain` — число, выраженное `0` или `1`, которое показывает, является ли заведение сетевым (для маленьких сетей могут встречаться ошибки):
#     - `0` — заведение не является сетевым;
#     - `1` — заведение является сетевым.
# - `seats` — количество посадочных мест.
#
# Файл `/datasets/rest_price.csv` содержит информацию о среднем чеке в заведениях общественного питания:
#
# - `price` — категория цен в заведении, например «средние», «ниже среднего», «выше среднего» и так далее;
# - `avg_bill` — строка, которая хранит среднюю стоимость заказа в виде диапазона, например:
#     - «Средний счёт: 1000–1500 ₽»;
#     - «Цена чашки капучино: 130–220 ₽»;
#     - «Цена бокала пива: 400–600 ₽».
#
#         и так далее;
#
# - `middle_avg_bill` — число с оценкой среднего чека, которое указано только для значений из столбца `avg_bill`, начинающихся с подстроки «Средний счёт»:
#     - Если в строке указан ценовой диапазон из двух значений, в столбец войдёт медиана этих двух значений.
#     - Если в строке указано одно число — цена без диапазона, то в столбец войдёт это число.
#     - Если значения нет или оно не начинается с подстроки «Средний счёт», то в столбец ничего не войдёт.
# - `middle_coffee_cup` — число с оценкой одной чашки капучино, которое указано только для значений из столбца `avg_bill`, начинающихся с подстроки «Цена одной чашки капучино»:
#     - Если в строке указан ценовой диапазон из двух значений, в столбец войдёт медиана этих двух значений.
#     - Если в строке указано одно число — цена без диапазона, то в столбец войдёт это число.
#     - Если значения нет или оно не начинается с подстроки «Цена одной чашки капучино», то в столбец ничего не войдёт.

# %% [markdown]
# ## Структура проекта
# 1. [Загрузка данных.](#1-загрузка-данных)
# 2. [Предобработка данных.](#2-предобработка-данных)
# 3. [Исследовательский анализ данных.](#3-исследовательский-анализ-данных)<br>
#     3.1. [Категории заведений.](#31-категории-заведений)<br>
#     3.2. [Количество заведений по районам.](#32-количество-заведений-по-районам)<br>
#     3.3. [Количество сетевых заведений.](#33-количество-сетевых-заведений)<br>
#     3.4. [Изучение количества посадочных мест.](#34-изучение-количества-посадочных-мест)<br>
#     3.5. [Исследование рейтингов.](#35-исследование-рейтингов)<br>
#     3.6. [Корреляция рейтинга с параметрами заведений.](#36-корреляция-рейтинга-с-параметрами-заведений)<br>
#     3.7. [Исследование сетевых заведений.](#37-исследование-сетевых-заведений)<br>
#     3.8. [Изучение вариации среднего чека в зависимости от района.](#38-изучение-вариации-среднего-чека-в-зависимости-от-района)<br>
# 4. [Выводы](#4-выводы)

# %% [markdown]
# ## 1. Загрузка данных

# %% [markdown]
# - Импорт необходимых библиотек:

# %%
# !pip install phik -U

# %%
# Импортируем необходимые библиотеки для анализа данных и построения графиков и диаграмм
import pandas as pd
import numpy as np

import seaborn as sns
import matplotlib.pyplot as plt

# Библиотека phik для анализа корреляций
import phik

# %% [markdown]
# <div class="alert alert-success">
# <b>✔️ Комментарий ревьюера v1:</b>
# <br>Ты правильно делаешь, что импортируешь все библиотеки отдельно в первой ячейке. Это правило хорошего тона, которое позволит твоим коллегам сразу увидеть все необходимые библиотеки для работы с твоим файлом.
# </div>

# %% [markdown]
# - Загрузка датасетов `rest_info` и `rest_price`:

# %%
df_rest_info = pd.read_csv("https://code.s3.yandex.net/datasets/rest_info.csv")
df_rest_price = pd.read_csv("https://code.s3.yandex.net/datasets/rest_price.csv")

# %% [markdown]
# - Вывод сведений о датасете `rest_info` и примера данных:

# %%
# Информация о датасете
df_rest_info.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 8406 entries, 0 to 8405
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   id        8406 non-null   str
#  1   name      8406 non-null   str
#  2   category  8406 non-null   str
#  3   address   8406 non-null   str
#  4   district  8406 non-null   str
#  5   hours     7870 non-null   str
#  6   rating    8406 non-null   float64
#  7   chain     8406 non-null   int64
#  8   seats     4795 non-null   float64
# dtypes: float64(2), int64(1), str(6)
# memory usage: 591.2 KB

# %%
# Выводим первые 5 строк датасета
df_rest_info.head()
# Out:
#                                  id                  name  category  \
# 0  0c3e3439a8c64ea5bf6ecd6ca6ae19f0                WoWфли      кафе
# 1  045780ada3474c57a2112e505d74b633        Четыре комнаты  ресторан
# 2  1070b6b59144425896c65889347fcff6                 Хазри      кафе
# 3  03ac7cd772104f65b58b349dc59f03ee  Dormouse Coffee Shop   кофейня
# 4  a163aada139c4c7f87b0b1c0b466a50f             Иль Марко  пиццерия
#
#                                address                         district  \
# 0           Москва, улица Дыбенко, 7/1  Северный административный округ
# 1   Москва, улица Дыбенко, 36, корп. 1  Северный административный округ
# 2       Москва, Клязьминская улица, 15  Северный административный округ
# 3  Москва, улица Маршала Федоренко, 12  Северный административный округ
# 4      Москва, Правобережная улица, 1Б  Северный административный округ
#
#                                                hours  rating  chain  seats
# ...

# %% [markdown]
# - Вывод сведений о датасете `rest_price` и примера данных:

# %%
# Информация о датасете
df_rest_price.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 4058 entries, 0 to 4057
# Data columns (total 5 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 4058 non-null   str
#  1   price              3315 non-null   str
#  2   avg_bill           3816 non-null   str
#  3   middle_avg_bill    3149 non-null   float64
#  4   middle_coffee_cup  535 non-null    float64
# dtypes: float64(2), str(3)
# memory usage: 158.6 KB

# %%
# Выводим первые 5 строк датасета
df_rest_price.head()
# Out:
#                                  id          price  \
# 0  045780ada3474c57a2112e505d74b633  выше среднего
# 1  1070b6b59144425896c65889347fcff6        средние
# 2  03ac7cd772104f65b58b349dc59f03ee            NaN
# 3  a163aada139c4c7f87b0b1c0b466a50f        средние
# 4  8a343546b24e4a499ad96eb7d0797a8a        средние
#
#                         avg_bill  middle_avg_bill  middle_coffee_cup
# 0       Средний счёт:1500–1600 ₽           1550.0                NaN
# 1         Средний счёт:от 1000 ₽           1000.0                NaN
# 2  Цена чашки капучино:155–185 ₽              NaN              170.0
# 3         Средний счёт:400–600 ₽            500.0                NaN
# 4                            NaN              NaN                NaN

# %% [markdown]
# - Количество пропусков в датасетах `rest_info` и `rest_price` в абсолютных значениях и в процентах:

# %%
# Подсчет пропусков в датасете rest_info
pd.DataFrame({"Количество": df_rest_info.isna().sum(), "Проценты": round(df_rest_info.isna().mean() * 100.0, 2)}).style.background_gradient(cmap='viridis')
# Out:
# <style type="text/css">
# #T_8df25_row0_col0, #T_8df25_row0_col1, #T_8df25_row1_col0, #T_8df25_row1_col1, #T_8df25_row2_col0, #T_8df25_row2_col1, #T_8df25_row3_col0, #T_8df25_row3_col1, #T_8df25_row4_col0, #T_8df25_row4_col1, #T_8df25_row6_col0, #T_8df25_row6_col1, #T_8df25_row7_col0, #T_8df25_row7_col1 {
#   background-color: #440154;
#   color: #f1f1f1;
# }
# #T_8df25_row5_col0 {
#   background-color: #46337f;
#   color: #f1f1f1;
# }
# #T_8df25_row5_col1 {
#   background-color: #463480;
#   color: #f1f1f1;
# }
# #T_8df25_row8_col0, #T_8df25_row8_col1 {
#   background-color: #fde725;
#   color: #000000;
# }
# </style>
# <table id="T_8df25">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8df25_level0_col0" class="col_heading level0 col0" >Количество</th>
#       <th id="T_8df25_level0_col1" class="col_heading level0 col1" >Проценты</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
# ...

# %%
# Подсчет пропусков в датасете rest_price
pd.DataFrame({"Количество": df_rest_price.isna().sum(), "Проценты": round(df_rest_price.isna().mean() * 100.0, 2)}).style.background_gradient(cmap='viridis')
# Out:
# <style type="text/css">
# #T_1afda_row0_col0, #T_1afda_row0_col1 {
#   background-color: #440154;
#   color: #f1f1f1;
# }
# #T_1afda_row1_col0, #T_1afda_row1_col1 {
#   background-color: #404688;
#   color: #f1f1f1;
# }
# #T_1afda_row2_col0, #T_1afda_row2_col1 {
#   background-color: #481a6c;
#   color: #f1f1f1;
# }
# #T_1afda_row3_col0, #T_1afda_row3_col1 {
#   background-color: #3a548c;
#   color: #f1f1f1;
# }
# #T_1afda_row4_col0, #T_1afda_row4_col1 {
#   background-color: #fde725;
#   color: #000000;
# }
# </style>
# <table id="T_1afda">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1afda_level0_col0" class="col_heading level0 col0" >Количество</th>
#       <th id="T_1afda_level0_col1" class="col_heading level0 col1" >Проценты</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1afda_level0_row0" class="row_heading level0 row0" >id</th>
#       <td id="T_1afda_row0_col0" class="data row0 col0" >0</td>
# ...

# %% [markdown]
# **Промежуточные выводы**:
# - в датасете `rest_info` 8406 записей, имеются пропуски в столбцах `hours` и `seats` в количестве 536 и 3611 соответственно, что составляет 6.4% и 42.9% от всего датасета;
# - в датасете `rest_price` 4058 записей, имеются пропуски в столбцах `price` и `avg_bill` в количестве 743 и 242 соответственно, или 18.3% и 6% от датасета;
# - значения в полях `middle_avg_bill` и `middle_coffee_cup` зависят от значения в поле `avg_bill`, поэтому пропуски в них необходимо изучать отдельно;
# - из соотношения количества строк в двух датасетах видно, что информация о ценах и среднем чеке есть лишь для 48.2% заведений (без учета наличия дубликатов); следовательно, исследование цен будет проводиться только над этой частью исходных данных;
# - названия столбцов соответствуют содержащимся в них данным и соглашениям об именовании snake case;
# - типы столбцов также соответствуют данным, за исключением столбца `chain` датасета `rest_info`, который можно привести к типу `bool`, и столбца `seats`, который имеет тип `float64`, вероятно, из-за имеющихся в нем пропусков.

# %% [markdown]
# <div class="alert alert-success">
# <b>✔️ Комментарий ревьюера v1:</b>
# <br>Первичный анализ данных выполнен верно. Ты используешь подходящие способы для анализа и делаешь верные выводы.
# </div>

# %% [markdown]
# - Исследуем пропуски в столбцах `middle_avg_bill` и `middle_coffee_cup` в зависимости от значений в столбце `avg_bill`:

# %%
# Количество пропусков в столбце middle_avg_bill для тех avg_bill, в которых указан средний счет
print("Количество пропусков в middle_avg_bill:", df_rest_price[df_rest_price['avg_bill'].notna() & df_rest_price['avg_bill'].str.startswith("Средний счёт")]['middle_avg_bill'].isna().sum())
print("Соответствующих avg_bill:", df_rest_price[df_rest_price['middle_avg_bill'].notna()]['avg_bill'].str.startswith("Средний счёт").sum())
# Out:
# Количество пропусков в middle_avg_bill: 0
# Соответствующих avg_bill: 3149

# %%
# Количество пропусков в столбце middle_avg_bill для тех avg_bill, в которых указан средний счет
print("Количество пропусков в middle_coffee_cup:", df_rest_price[df_rest_price['avg_bill'].notna() & df_rest_price['avg_bill'].str.startswith("Цена чашки капучино")]['middle_coffee_cup'].isna().sum())
print("Соответствующих avg_bill:", df_rest_price[df_rest_price['middle_coffee_cup'].notna()]['avg_bill'].str.startswith("Цена чашки капучино").sum())
# Out:
# Количество пропусков в middle_coffee_cup: 0
# Соответствующих avg_bill: 535

# %% [markdown]
# **Вывод**: Пропусков в полях `middle_avg_bill` и `middle_coffee_cup` для соответствующих значений в `avg_bill` не содержится.
#
# - Объединим два датасета в один при помощи left join:

# %%
# Объединение датасетов
df = df_rest_info.merge(df_rest_price, how="left", on="id")

# Вывод первых 5 строк объединенного датасета
df.head()
# Out:
#                                  id                  name  category  \
# 0  0c3e3439a8c64ea5bf6ecd6ca6ae19f0                WoWфли      кафе
# 1  045780ada3474c57a2112e505d74b633        Четыре комнаты  ресторан
# 2  1070b6b59144425896c65889347fcff6                 Хазри      кафе
# 3  03ac7cd772104f65b58b349dc59f03ee  Dormouse Coffee Shop   кофейня
# 4  a163aada139c4c7f87b0b1c0b466a50f             Иль Марко  пиццерия
#
#                                address                         district  \
# 0           Москва, улица Дыбенко, 7/1  Северный административный округ
# 1   Москва, улица Дыбенко, 36, корп. 1  Северный административный округ
# 2       Москва, Клязьминская улица, 15  Северный административный округ
# 3  Москва, улица Маршала Федоренко, 12  Северный административный округ
# 4      Москва, Правобережная улица, 1Б  Северный административный округ
#
#                                                hours  rating  chain  seats  \
# ...

# %% [markdown]
# <div class="alert alert-warning">
# <b>⚠️ Комментарий ревьюера v1:</b>
# <br>После создания новых таблиц, не забывай проверять их размерность, чтобы убедиться, что ничего не потерялось.
# </div>

# %% [markdown]
# <div class="alert alert-info">
# <b>Комментарий студента:</b>
# <br> Добавляю вывод info(), ничего не пропало:
# </div>

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 8406 entries, 0 to 8405
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 8406 non-null   str
#  1   name               8406 non-null   str
#  2   category           8406 non-null   str
#  3   address            8406 non-null   str
#  4   district           8406 non-null   str
#  5   hours              7870 non-null   str
#  6   rating             8406 non-null   float64
#  7   chain              8406 non-null   int64
#  8   seats              4795 non-null   float64
#  9   price              3315 non-null   str
#  10  avg_bill           3816 non-null   str
#  11  middle_avg_bill    3149 non-null   float64
#  12  middle_coffee_cup  535 non-null    float64
# dtypes: float64(4), int64(1), str(8)
# memory usage: 853.9 KB

# %% [markdown]
# ## 2. Предобработка данных
#
# - Преобразуем тип данных столбца `chain` в `bool`:

# %%
# Преобразуем тип столбца
df['chain'] = df['chain'].astype('bool')

# Проверяем результат преобразования
df['chain'].dtype
# Out:
# dtype('bool')

# %% [markdown]
# - Как было замечено ранее, количество пропусков в столбце `seats` составляет 42.9%. Вероятно, большое количество пропусков в этом столбце связано с тем, что некоторые категории заведений могут работать преимущественно на вынос (кофейни, кафе, сети быстрого питания, столовые); также количество мест может иметь сезонные колебания или меняться иным образом (летние веранды, дополнительные столики, фудкорты и проч.). Соответствующее поле в карточке заведения не является обязательным, и владельцы не заполняют его. На следующей диаграмме отображено количество пропусков в зависимости от категории заведения:

# %%
# Строим столбчатую диаграмму доли пропусков в поле seats в зависимости от категории заведения
missing_seats_ratio = df[df['seats'].isna()].groupby('category')['id'].count() / df.groupby('category')['id'].count() * 100.0
missing_seats_ratio = missing_seats_ratio.sort_values(ascending=False)
missing_seats_ratio.plot(
    title="Пропуски в поле seats по категориям заведений, %",
    kind='bar',
    color='skyblue',
    xlabel="Категории",
    legend=False,
    rot=45,
    grid=True)

plt.show()

# %% [markdown]
# <div class="alert alert-danger">
# <b>❌ Комментарий ревьюера v1:</b>
# <br>Графики должны быть обязательно отсортированы, будь то диаграмма или boxplot (в случае с boxplot'ом нужно сортировать по медиане, а сортировку можно произвести в таблице, а по ней уже строить графики). Этот комментарий относится ко всем графикам во всем проекте. Проверь наличие сортировки в каждом графике самостоятельно
# </div>

# %% [markdown]
# <div class="alert alert-info">
# <b>Комментарий студента:</b>
# <br>
# Сделал
# </div>

# %% [markdown]
# - Заменим пропуски в количестве посадочных мест на значение-индикатор `-1` и приведем столбец к типу `int64`:

# %%
# Замена пропусков на значение-индикатор
df.loc[df['seats'].isna(), 'seats'] = -1

# Приведение столбца к типу int64
df['seats'] = df['seats'].astype('int64')
df['seats'].dtype
# Out:
# dtype('int64')

# %% [markdown]
# <div class="alert alert-warning">
# <b>⚠️ Комментарий ревьюера v1:</b>
# <br>В данном случае пропуски можно вообще не заполнять. Заглушку можно использовать, но важно в дальнейшем не забыть про нее
# </div>

# %% [markdown]
# - Пропуски в столбце `hours` встречаются, в основном, в категории "кафе" и в наибольшей степени в ЮВАО, округом с наибольшей концентрацией мигрантов по Москве. В данных для этого округа присутствует много этнических заведений, ориентированных, в большой степени, на знакомых посетителей из соответствующего контингента.
#
# Таких пропусков всего 6.4%, заменим их значением-индикатором `"Не определено"`:

# %%
# Строим горизонтальные столбчатые диаграммы в subplots с общей осью x
fig, axes = plt.subplots(nrows=2, ncols=1, sharex=True, figsize=(12, 6))

s1 = df.groupby('category')['hours'].agg(lambda x: x.isna().mean()) * 100
s2 = df.groupby('district')['hours'].agg(lambda x: x.isna().mean()) * 100
s1.sort_values().plot(kind='barh', ax=axes[0], title="Пропуски в столбце hours по категориям, %", ylabel="Категории", grid=True)
s2.sort_values().plot(kind='barh', ax=axes[1], title="Пропуски в столбце hours по районам, %", ylabel="Районы", grid=True)

plt.tight_layout()
plt.show()

# Заменяем пропуски на значение-индикатор
df.loc[df['hours'].isna(), 'hours'] = "Не определено"

# %% [markdown]
# - Проверим данные на дубликаты по столбцам `name` и `address`, приведя значения в этих полях к нижнему регистру.
# - В случае нахождения дубликатов удалим их.

# %%
# Приводим название и адрес к нижнему регистру
df[['name', 'address']] = df[['name', 'address']].agg(lambda x: x.str.lower())

print('Количество дубликатов:', df.duplicated(subset=['name', 'address']).sum())

# Удаляем дубликаты
df.drop_duplicates(subset = ['name', 'address'], inplace = True)
# Out:
# Количество дубликатов: 4

# %% [markdown]
# <div class="alert alert-success">
# <b>✔️ Комментарий ревьюера v1:</b>
# <br>Проверка на дубликаты выполнена!
# </div>

# %% [markdown]
# - Для дальнейших исследований создадим столбец `is_24_7` с обозначением того, что заведение работает ежедневно и круглосуточно:
#     - логическое значение `True` — если заведение работает ежедневно и круглосуточно;
#     - логическое значение `False` — в противоположном случае.

# %%
# Создание дополнительного столбца
df['is_24_7'] = df['hours'].str.lower().str.contains('ежедневно') & df['hours'].str.lower().str.contains('круглосуточно')

# %% [markdown]
# <div class="alert alert-success">
# <b>✔️ Комментарий ревьюера v1:</b>
# <br>Новый столбец создан корректно
# </div>

# %% [markdown]
# **Промежуточные выводы**:
# - На этапе предобработки данных был выполнен подсчет и анализ пропусков в столбцах `seats` и `hours`. Были установлены категории заведений и район Москвы, для которых наиболее характерны пропуски, сделано предположение об их причине. Пропуски заменены на значения-индикаторы `-1` и `"Не определено"`;
# - данные были проанализированы на наличие дубликатов с одинаковым (с точностью до регистра символов) названием и адресом. Были найдены 4 дубликата, которые были удалены;
# - Для удобства анализа столбцы `chain` и `seats` были приведены к типам `bool` и `int64` соответственно;
# - Для дальнейших исследований был создан столбец `is_24_7`, указывающий на то, работает ли заведение ежедневно и круглосуточно.

# %% [markdown]
# <div class="alert alert-success">
# <b>✔️ Комментарий ревьюера v1:</b>
# <br>С предобработкой закончили, можно переходить к анализу!
# </div>

# %% [markdown]
# ## 3. Исследовательский анализ данных

# %% [markdown]
# ### 3.1. Категории заведений
#
# - Получим список категорий заведений и количество заведений каждой категории:

# %%
# Количество заведений по категориям
df.groupby('category').size().sort_values(ascending=False).to_frame().style.background_gradient(cmap='viridis')
# Out:
# <style type="text/css">
# #T_71325_row0_col0 {
#   background-color: #fde725;
#   color: #000000;
# }
# #T_71325_row1_col0 {
#   background-color: #95d840;
#   color: #000000;
# }
# #T_71325_row2_col0 {
#   background-color: #1e9b8a;
#   color: #f1f1f1;
# }
# #T_71325_row3_col0 {
#   background-color: #3c4f8a;
#   color: #f1f1f1;
# }
# #T_71325_row4_col0 {
#   background-color: #433d84;
#   color: #f1f1f1;
# }
# #T_71325_row5_col0 {
#   background-color: #453882;
#   color: #f1f1f1;
# }
# #T_71325_row6_col0 {
#   background-color: #460b5e;
#   color: #f1f1f1;
# }
# #T_71325_row7_col0 {
#   background-color: #440154;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_71325">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_71325_level0_col0" class="col_heading level0 col0" >0</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >category</th>
#       <th class="blank col0" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
# ...

# %% [markdown]
# - Построим столбчатую диаграмму для визуализации полученных значений:

# %%
df.groupby('category').size().sort_values(ascending=False).plot(
    title="Количество заведений по категориям",
    kind="bar",
    rot=45,
    xlabel="Категории",
    ylabel="Количество",
    figsize=(8, 4),
    grid=True
    )

plt.show()

# %% [markdown]
# <div class="alert alert-warning">
# <b>⚠️ Комментарий ревьюера v1:</b>
# <br>Не забывай подписывать обе оси у графика
# </div>

# %% [markdown]
# <div class="alert alert-info">
# <b>Комментарий студента:</b>
# <br>
# Сделал
# </div>

# %% [markdown]
# Наиболее распространенные категории заведений - кафе, рестораны и кофейни (2376, 2042 и 1413 соответственно)

# %% [markdown]
# ### 3.2. Количество заведений по районам
# - Посчитаем количество заведений по районам:

# %%
# Количество заведений по районам
df.groupby('district').size().sort_values(ascending=False).to_frame().style.background_gradient(cmap='viridis')
# Out:
# <style type="text/css">
# #T_73714_row0_col0 {
#   background-color: #fde725;
#   color: #000000;
# }
# #T_73714_row1_col0 {
#   background-color: #39568c;
#   color: #f1f1f1;
# }
# #T_73714_row2_col0, #T_73714_row3_col0 {
#   background-color: #39558c;
#   color: #f1f1f1;
# }
# #T_73714_row4_col0 {
#   background-color: #3c4f8a;
#   color: #f1f1f1;
# }
# #T_73714_row5_col0 {
#   background-color: #3f4788;
#   color: #f1f1f1;
# }
# #T_73714_row6_col0 {
#   background-color: #443983;
#   color: #f1f1f1;
# }
# #T_73714_row7_col0 {
#   background-color: #453882;
#   color: #f1f1f1;
# }
# #T_73714_row8_col0 {
#   background-color: #440154;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_73714">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_73714_level0_col0" class="col_heading level0 col0" >0</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >district</th>
#       <th class="blank col0" >&nbsp;</th>
#     </tr>
#   </thead>
# ...

# %% [markdown]
# - Построим горизонтальную столбчатую диаграмму для визуализации полученных значений:

# %%
# Построение горизонтальной столбчатой диаграммы
df.groupby('district').size().sort_values().plot(
    title="Количество заведений по районам",
    kind="barh",
    xlabel="Количество",
    ylabel="Районы",
    figsize=(12, 4),
    grid=True
    )
plt.show()

# %% [markdown]
# - Наименьшее  количество заведений - в Северо-Западном административном округе (409). Это в среднем примерно в 2 раза меньше, чем в других округах (исключая ЦАО);
# - наибольшее количество заведений (2242) - в Центральном административном округе. Исследуем их отдельно по категориям:

# %%
# Датафрейм с данными по ЦАО
df_cao = df[df['district'] == 'Центральный административный округ']

# Составной датафрейм для построения диаграммы
df_cat_bar = pd.DataFrame(
            {"ЦАО": df_cao.groupby('category').size(),
             "Москва": df.groupby('category').size()}).sort_values(by='ЦАО', ascending=False)

# Строим столбчатую диаграмму по ЦАО и всей Москве
df_cat_bar.plot(
    title="Количество заведений по категориям в ЦАО и всей Москве",
    kind="bar",
    rot=45,
    figsize=(8, 4),
    xlabel="Категории",
    ylabel="Количество",
    grid=True,
    )

plt.show()

# %% [markdown]
# - Доля ресторанов и баров/пабов в ЦАО наибольшая относительно других районов;
# - доля булочных, заведений быстрого питания и столовых меньше относительно прочих районов.

# %% [markdown]
# <div class="alert alert-success">
# <b>✔️ Комментарий ревьюера v1:</b>
# <br>В этом задании тоже все корректно. Полученные выводы логичные и соотносятся с реальностью)
# </div>

# %% [markdown]
# ### 3.3. Количество сетевых заведений.
# - Посчитаем количество сетевых и несетевых заведений:

# %%
# Количество сетевых и несетевых заведений:
print(f"Количество сетевых заведений и их доля: {df['chain'].sum()}, {round(df['chain'].mean()*100, 2)}%")
net_percent = round(df['chain'].mean()*100, 2)

plt.pie([net_percent, 100-net_percent], labels=["Сетевые", "Несетевые"], shadow=True)
plt.title("Сетевые и несетевые заведения")
plt.show()
# Out:
# Количество сетевых заведений и их доля: 3203, 38.12%

# %% [markdown]
# <div class="alert alert-warning">
# <b>⚠️ Комментарий ревьюера v1:</b>
# <br>Так как у нас всего две категории, то тут отлично бы подошла круговая диаграмма с подписанными долями.
# </div>

# %% [markdown]
# <div class="alert alert-info">
# <b>Комментарий студента:</b>
# <br>
# Сделал
# </div>

# %% [markdown]
# - Построим диаграмму количества сетевых и прочих заведений по районам:

# %%
# Построение диаграммы количества сетевых и несетевых заведений по категориям
(df.groupby('category')['chain'].mean()*100).sort_values(ascending=False).plot(
    title="Доля количества сетевых заведений по категориям, %",
    kind="bar",
    figsize=(8, 4),
    xlabel="Категории",
    ylabel="Доля сетевых заведений",
    grid=True,
    rot=45
    )

plt.show()

# %% [markdown]
# <div class="alert alert-danger">
# <b>❌ Комментарий ревьюера v1:</b>
# <br>Здесь нужно взять количество сетевых заведений в каждой категории и разделить на общее количество заведений в этой категории. Допустим есть 100 булочных. Из них 60 сетевых. 60/100=0.6 Это и будет доля сетевых заведений внутри этой категории. Не забудь добавить сортировку
# </div>

# %% [markdown]
# <div class="alert alert-info">
# <b>Комментарий студента:</b>
# <br>
# Сделал
# </div>

# %% [markdown]
# - Сетевые заведения составляют 38.1% от общего количества;
# - наибольшая доля сетевых заведений среди кофеен, булочных и пиццерий (больше 50%); наименьшая - среди баров/пабов, столовых и кафе.

# %% [markdown]
# ### 3.4. Изучение количества посадочных мест.
#
# - Построим гистограмму распределения количества посадочных мест по всем данным:

# %%
# Отфильтруем заведения, исключая значения-индикаторы -1
df_seats = df[df['seats'] != -1]

# Построим гистограмму распределения посадочных мест
plt.figure(figsize=(12, 4))
sns.histplot(data=df_seats, x='seats', kde=True)

plt.xticks(np.arange(0, 1300, step=50), rotation=90)
plt.title("Распределение количества посадочных мест по всем заведениям")
plt.xlabel("Количество мест")
plt.ylabel("Количество заведений")
plt.show()

# %% [markdown]
# - Пик достигается на значениях около 50. Распределение имеет тяжелый правый хвост и признаки присутствия аномальных значений (больше 600 посадочных мест).
#
# Построим диаграмму размаха для различных категорий заведений:

# %%
# Построим диаграмму размаха для посадочных мест
plt.figure(figsize=(12, 4))
ax = sns.boxplot(data=df,
                 x='seats',
                 y='category',
                 order=df.groupby('category')['seats'].median().sort_values(ascending=False).index)
plt.title("Распределение количества посадочных мест по категориям заведений")
plt.xlabel("Количество мест")
plt.ylabel("Категория")
plt.show()

# %% [markdown]
# <div class="alert alert-success">
# <b>✔️ Комментарий ревьюера v1:</b>
# <br>Использовать боксплоты для анализа - верное решение
# </div>

# %% [markdown]
# - **В данных присутствуют аномальные значения:**
#     1. у некоторых заведений количество посадочных мест 0. Это могут быть заведения, которые работают исключительно на вынос;
#     2. встречается аномально большое количество посадочных мест - больше 700. Все такие данные относятся к Восточному и Западному административным округам, причем для всех таких заведений из ЗАО указаны значения 920, 1200 и 1288, а для заведений из ВАО - 760 и 1040. Эти данные очевидно являются ошибочными и могут быть исключены из исследования.

# %%
# Посчитаем количество выбросов по районам
df_seats[df_seats['seats'] >= 700].groupby(['district', 'seats']).size()
# Out:
# district                          seats
# Восточный административный округ  760       1
#                                   1040      4
# Западный административный округ   920       2
#                                   1200      1
#                                   1288     11
# dtype: int64

# %%
# Удаляем явные выбросы
df_seats = df_seats[df_seats['seats'] < 700]

# %% [markdown]
# - Значения более 300 также с некоторой долей вероятности могут считаться выбросами. Если одинаковые большие значения указаны для заведений, находящихся по одному адресу, вероятно, эти заведения располагаются в фудкорте, и для каждого из них указана емкость всего фудкорта. Посчитаем их количество по районам (5 самых больших):

# %%
# Посчитаем заведения с количеством мест более 500 по районам
df_seats[df_seats['seats'] > 300].groupby(['district', 'seats']).size().sort_values(ascending=False).head()
# Out:
# district                            seats
# Северный административный округ     625      23
# Центральный административный округ  350      21
#                                     500      17
# Южный административный округ        320      15
# Центральный административный округ  480      13
# dtype: int64

# %% [markdown]
# - Выведем адреса, по которым располагается наибольшее количество таких заведений (вероятные фудкорты):

# %%
# Выведем первые 5 адресов с наибольшим количеством заведений и 
display(df_seats[df_seats['seats'] > 300].groupby(['address', 'seats']).size().sort_values(ascending=False).head())

# Заведения с количеством мест 625
print("Адреса заведений с количеством мест 625:")
display(df_seats[df_seats['seats'] == 625]['address'])
# Out:
# address                             seats
# москва, лесная улица, 20, стр. 3    500      16
# москва, пресненская набережная, 2   350      16
# москва, улица вавилова, 3           320      14
# москва, комсомольский проспект, 28  400       9
# москва, пятницкая улица, 29         306       8
# dtype: int64
# Адреса заведений с количеством мест 625:
# 1326       москва, ленинградский проспект, 69, стр. 1
# 1351      москва, ленинградский проспект, 78, корп. 1
# 1355      москва, ленинградский проспект, 77, корп. 1
# 1367      москва, ленинградский проспект, 72, корп. 1
# 1380      москва, ленинградский проспект, 75, корп. 1
# 1385       москва, ленинградский проспект, 69, стр. 1
# 1393      москва, ленинградский проспект, 72, корп. 1
# 1442      москва, ленинградский проспект, 72, корп. 1
# 1446      москва, ленинградский проспект, 80, корп. 1
# 1464      москва, ленинградский проспект, 74, корп. 1
# 1475      москва, ленинградский проспект, 80, корп. 1
# ...

# %% [markdown]
# - Заведения с количеством мест 625 расположены по разным адресам и не могут располагаться в одном фудкорте, поэтому эти значения тоже являются некорректными и могут быть удалены:

# %%
df_seats = df_seats[df_seats['seats'] != 625]

# %% [markdown]
# - Посчитаем наиболее характерное количество посадочных мест для разных категорий (медиану и среднее):

# %%
df_seats_agg = df_seats.groupby('category')['seats'].agg(['median', 'mean']).sort_values(by='median', ascending=False)
df_seats_agg.index.name = "Категория"
df_seats_agg.columns = ["Медиана", "Среднее"]


# Выведем медиану количества мест
display(df_seats_agg
        .style
        .background_gradient(cmap='viridis'))

# А также в виде столбчатой диаграммы
df_seats_agg.plot(
    title="Характерное количество мест по категориям заведений",
    kind="bar",
    rot=45,
    xlabel="Категории",
    ylabel="Количество мест",
    figsize=(8, 4),
    grid=True
    )
plt.show()
# Out:
# <style type="text/css">
# #T_63450_row0_col0, #T_63450_row0_col1 {
#   background-color: #fde725;
#   color: #000000;
# }
# #T_63450_row1_col0 {
#   background-color: #90d743;
#   color: #000000;
# }
# #T_63450_row1_col1 {
#   background-color: #c5e021;
#   color: #000000;
# }
# #T_63450_row2_col0 {
#   background-color: #6ece58;
#   color: #000000;
# }
# #T_63450_row2_col1 {
#   background-color: #1f978b;
#   color: #f1f1f1;
# }
# #T_63450_row3_col0 {
#   background-color: #40bd72;
#   color: #f1f1f1;
# }
# #T_63450_row3_col1 {
#   background-color: #472e7c;
#   color: #f1f1f1;
# }
# #T_63450_row4_col0 {
#   background-color: #287c8e;
#   color: #f1f1f1;
# }
# #T_63450_row4_col1 {
#   background-color: #306a8e;
#   color: #f1f1f1;
# }
# #T_63450_row5_col0 {
#   background-color: #375a8c;
#   color: #f1f1f1;
# }
# #T_63450_row5_col1 {
#   background-color: #424186;
#   color: #f1f1f1;
# }
# #T_63450_row6_col0 {
#   background-color: #481668;
#   color: #f1f1f1;
# }
# ...

# %% [markdown]
# Медиана и среднее значительно различаются из-за оставшихся выбросов в данных. Вероятно, это происходит из-за заведений из фудкортов, у которых указано количество посадочных мест всего фудкорта.

# %% [markdown]
# ### 3.5. Исследование рейтингов

# %% [markdown]
# - Построим диаграмму распределения рейтингов по всем заведениям:

# %%
# Построим гистограмму распределения рейтингов
plt.figure(figsize=(8, 4))
sns.histplot(data=df_seats, x='rating', kde=True, bins=50)

plt.title("Распределение рейтингов по всем заведениям")
plt.xlabel("Рейтинг")
plt.ylabel("Количество заведений")
plt.show()

# %% [markdown]
# - А также диаграмму размаха для каждой категории:

# %%
# Построим диаграмму размаха для рейтингов по категориям
plt.figure(figsize=(12, 4))
ax = sns.boxplot(data=df, 
                 x='rating', 
                 y='category', 
                 showmeans=True,
                 meanprops={
                    "marker": "o",
                    "markerfacecolor": "white",
                    "markeredgecolor": "black",
                    "markersize": 8
                },
                order=df.groupby('category')['rating'].mean().sort_values(ascending=False).index
                )
plt.title("Распределение рейтингов по категориям заведений")
plt.xlabel("Рейтинг")
plt.ylabel("Категория")
plt.show()

# %%
print("Средние рейтинги по категориям:")
display(df.groupby('category')['rating'].mean().sort_values(ascending=False).to_frame().style.format('{:.2f}').background_gradient(cmap='viridis'))
# Out:
# Средние рейтинги по категориям:
# <style type="text/css">
# #T_36f35_row0_col0 {
#   background-color: #fde725;
#   color: #000000;
# }
# #T_36f35_row1_col0 {
#   background-color: #5ac864;
#   color: #000000;
# }
# #T_36f35_row2_col0 {
#   background-color: #4ac16d;
#   color: #000000;
# }
# #T_36f35_row3_col0 {
#   background-color: #38b977;
#   color: #f1f1f1;
# }
# #T_36f35_row4_col0 {
#   background-color: #2eb37c;
#   color: #f1f1f1;
# }
# #T_36f35_row5_col0 {
#   background-color: #228b8d;
#   color: #f1f1f1;
# }
# #T_36f35_row6_col0 {
#   background-color: #3e4989;
#   color: #f1f1f1;
# }
# #T_36f35_row7_col0 {
#   background-color: #440154;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_36f35">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_36f35_level0_col0" class="col_heading level0 col0" >rating</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >category</th>
#       <th class="blank col0" >&nbsp;</th>
# ...

# %% [markdown]
# - Средние рейтинги выше у баров/пабов, самые низкие - у кафе, столовых, заведений быстрого питания. У остальных категорий заведений - примерно на одном уровне;
# - наибольший диапазон рейтингов - у кафе, заведений быстрого питания, наименьший - у булочных и пиццерий.

# %% [markdown]
# <div class="alert alert-warning">
# <b>⚠️ Комментарий ревьюера v1:</b>
# <br>Брать медиану по фиксированным значениям (она есть на боксплотах) от 1 до 5 - нецелесообразно. Лучше для расчета рейтингов использовать среднее. Так мы четче увидим разницу между категориями
# </div>

# %% [markdown]
# <div class="alert alert-info">
# <b>Комментарий студента:</b>
# <br>
# Добавил отображение средних рейтингов на боксплоте и отдельно.
# </div>

# %% [markdown]
# ### 3.6. Корреляция рейтинга с параметрами заведений

# %% [markdown]
# - Построим матрицу корреляций рейтинга со следующими параметрами:
#     1. категория;
#     2. район;
#     3. принадлежность к сетевым;
#     4. количество мест;
#     5. ценовая категория;
#     6. средний чек;
#     7. является ли заведение круглосуточным.

# %%
# Вычислим матрицу корреляций
df_corr = phik.phik_matrix(df[['rating', 'category', 'chain', 'seats', 'price', 'is_24_7']], interval_cols=['rating', 'seats'])

# Построим тепловую карту корреляций
plt.figure(figsize=(8,6))
plt.title("Корреляция рейтинга с параметрами заведений")
sns.heatmap(data=df_corr, annot=True, fmt='.2f', linewidths=0.5, cmap='viridis')
plt.show()

# %% [markdown]
# <div class="alert alert-warning">
# <b>⚠️ Комментарий ревьюера v1:</b>
# <br>Параметр rating можно исключить чтобы не отображалась его корреляция с самим собой. Тогда матрица превратится в столбик
# </div>

# %% [markdown]
# - Наибольшую корреляцию (0.22) рейтинг показывает с ценовой категорией. Однако ее абсолютное значение невелико, поэтому необходимо исследовать эту корреляцию дополнительно с использованием числового параметра `middle_avg_bill`.
# - Средний чек имеет одно аномальное значение (35000 р.), причем по указанному адресу заведений общественного питания нет. Эту запись следует удалить.

# %%
# Удалим строку с аномально большим чеком
df = df[(df['middle_avg_bill'].isna()) | (df['middle_avg_bill'] < 35000)]

# Построим график совместного распределения для столбцов `rating` и `middle_avg_bill`
plt.figure(figsize=(8,6))
sns.jointplot(data=df, x='rating', y='middle_avg_bill')
plt.suptitle('Совместное распределение рейтинга и среднего чека')
plt.xlabel("Рейтинг")
plt.ylabel("Средний чек, р.")
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# - Можно заметить, что заведения со средним чеком больше 3000 р. за редким исключением имеют рейтинг более 4, а рейтинг 2.5 и ниже почти всегда у заведений с чеком менее 1000 р.

# %% [markdown]
# <div class="alert alert-danger">
# <b>❌ Комментарий ревьюера v1:</b>
# <br>ССамая сильная корреляция со столбцом price и её нужно изучить. Чтобы изучить взаимосвязи с категориями цен, тебе нужно рассчитать среднее или медианное значение в каждой из них
# </div>

# %% [markdown]
# <div class="alert alert-info">
# <b>Комментарий студента:</b>
# <br>
# Добавил, изменил вывод
# </div>

# %% [markdown]
# - Расчитаем среднее и медиану рейтинга в каждой ценовой категории:

# %%
# Расчет и отображение среднего и медианного рейтинга в ценовых категориях
df_price_agg = df_seats.groupby('price')['rating'].agg(['median', 'mean']).sort_values(by='median', ascending=False)
df_price_agg.index.name = "Ценовая категория"
df_price_agg.columns = ["Медиана", "Среднее"]


# Выведем медиану количества мест
display(df_price_agg
        .style
        .background_gradient(cmap='viridis'))

# Строим столбчатую диаграмму по ЦАО и всей Москве
df_price_agg.plot(
    title="Средние значения и медианы рейтинга по ценовым категориям",
    kind="bar",
    figsize=(8, 4),
    xlabel="Ценовая категория",
    ylabel="Рейтинг",
    grid=True,
    rot=0
    )
plt.show()
# Out:
# <style type="text/css">
# #T_7c9a4_row0_col0, #T_7c9a4_row0_col1, #T_7c9a4_row1_col0 {
#   background-color: #fde725;
#   color: #000000;
# }
# #T_7c9a4_row1_col1 {
#   background-color: #6ece58;
#   color: #000000;
# }
# #T_7c9a4_row2_col0 {
#   background-color: #21908d;
#   color: #f1f1f1;
# }
# #T_7c9a4_row2_col1 {
#   background-color: #287d8e;
#   color: #f1f1f1;
# }
# #T_7c9a4_row3_col0, #T_7c9a4_row3_col1 {
#   background-color: #440154;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_7c9a4">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7c9a4_level0_col0" class="col_heading level0 col0" >Медиана</th>
#       <th id="T_7c9a4_level0_col1" class="col_heading level0 col1" >Среднее</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Ценовая категория</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
# ...

# %% [markdown]
# - Видна связь среднего рейтинга и ценовой категории, однако очевидно, что более высокие цены сами по себе не могут являться причиной более высоких рейтингов - зависимость, скорее, обратная.

# %% [markdown]
# ### 3.7. Исследование сетевых заведений

# %% [markdown]
# - Найдем 15 самых популярных сетевых заведений в Москве:

# %%
# Получим 15 наиболее популярных (по количеству заведений) сетей
top15 = df[df['chain']].groupby(['name', 'category']).size().sort_values(ascending=False).head(15)
top15.index.names = ("Сеть", "Категория")
display(top15
        .to_frame(name="Количество")
        .style
        .background_gradient(cmap='viridis'))
# Out:
# <style type="text/css">
# #T_c7c7e_row0_col0 {
#   background-color: #fde725;
#   color: #000000;
# }
# #T_c7c7e_row1_col0 {
#   background-color: #1f9e89;
#   color: #f1f1f1;
# }
# #T_c7c7e_row2_col0 {
#   background-color: #1f998a;
#   color: #f1f1f1;
# }
# #T_c7c7e_row3_col0 {
#   background-color: #20928c;
#   color: #f1f1f1;
# }
# #T_c7c7e_row4_col0 {
#   background-color: #228d8d;
#   color: #f1f1f1;
# }
# #T_c7c7e_row5_col0 {
#   background-color: #26828e;
#   color: #f1f1f1;
# }
# #T_c7c7e_row6_col0 {
#   background-color: #375a8c;
#   color: #f1f1f1;
# }
# #T_c7c7e_row7_col0 {
#   background-color: #404588;
#   color: #f1f1f1;
# }
# #T_c7c7e_row8_col0 {
#   background-color: #443b84;
#   color: #f1f1f1;
# }
# #T_c7c7e_row9_col0 {
#   background-color: #46327e;
#   color: #f1f1f1;
# }
# #T_c7c7e_row10_col0 {
#   background-color: #482173;
#   color: #f1f1f1;
# }
# #T_c7c7e_row11_col0 {
#   background-color: #471063;
#   color: #f1f1f1;
# }
# #T_c7c7e_row12_col0 {
# ...

# %% [markdown]
# - Посчитаем медиану и среднее значение рейтинга по категориям для 15 наиболее популярных сетей:

# %%
# Отфильтруем строки с заведениями из топ-15 сетей
top15_names_set = set(top15.index.get_level_values("Сеть"))
df_top15 = df[df['name'].isin(set(top15_names_set))]

top15_rating = df_top15.groupby('category')['rating'].agg(['mean', 'median'])
top15_rating.index.name = "Категория"
top15_rating.columns = ["Среднее", "Медиана"]

display(top15_rating
        .style
        .format('{:.2f}')
        .background_gradient(cmap='viridis'))
# Out:
# <style type="text/css">
# #T_eec1f_row0_col0, #T_eec1f_row0_col1 {
#   background-color: #fde725;
#   color: #000000;
# }
# #T_eec1f_row1_col0 {
#   background-color: #c0df25;
#   color: #000000;
# }
# #T_eec1f_row1_col1 {
#   background-color: #90d743;
#   color: #000000;
# }
# #T_eec1f_row2_col0 {
#   background-color: #297a8e;
#   color: #f1f1f1;
# }
# #T_eec1f_row2_col1, #T_eec1f_row3_col1, #T_eec1f_row4_col1 {
#   background-color: #31688e;
#   color: #f1f1f1;
# }
# #T_eec1f_row3_col0 {
#   background-color: #30698e;
#   color: #f1f1f1;
# }
# #T_eec1f_row4_col0 {
#   background-color: #1e9d89;
#   color: #f1f1f1;
# }
# #T_eec1f_row5_col0, #T_eec1f_row5_col1 {
#   background-color: #440154;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_eec1f">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_eec1f_level0_col0" class="col_heading level0 col0" >Среднее</th>
#       <th id="T_eec1f_level0_col1" class="col_heading level0 col1" >Медиана</th>
# ...

# %% [markdown]
# - Наименьший рейтинг у ресторанов, наивысший - у булочных и сетей быстрого питания.
# - Медиана для ресторанов и кофеен отличается от среднего, что говорит о наличии выбросов.
#
# - Построим диаграмму размаха для этих данных:

# %%
# Построим диаграмму размаха для рейтинга
plt.figure(figsize=(12, 4))
ax = sns.boxplot(data=df_top15,
                 x='rating', 
                 y='category',
                 order=df_top15.groupby('category')['rating'].mean().sort_values(ascending=False).index,
                 showmeans=True,
                 meanprops={
                    "marker": "o",
                    "markerfacecolor": "white",
                    "markeredgecolor": "black",
                    "markersize": 8
                },)
plt.title("Распределение рейтинга по категориям топ-15 сетевых заведений")
plt.xlabel("Рейтинг")
plt.ylabel("Категория")
plt.show()

# %% [markdown]
# Можно видеть, что для ресторанов и кофеен, а также для кафе присутствуют рейтинги ниже 3.5, что говорит о неравномерном качестве сетевых заведений этих категорий.

# %% [markdown]
# <div class="alert alert-success">
# <b>✔️ Комментарий ревьюера v1:</b>
# <br>Отлично! Выводы верные
# </div>

# %% [markdown]
# ### 3.8. Изучение вариации среднего чека в зависимости от района
#
# - Посчитаем значение медианы и среднего для среднего чека по районам:

# %%
# Отфильтруем строки с заведениями из топ-15 сетей
top15_rating = df.groupby('district')['middle_avg_bill'].agg(['mean', 'median']).sort_values(by='median', ascending=False)
top15_rating.index.name = "Категория"
top15_rating.columns = ["Среднее", "Медиана"]

display(top15_rating
        .style
        .format('{:.2f}')
        .background_gradient(cmap='viridis'))
# Out:
# <style type="text/css">
# #T_f88e7_row0_col0 {
#   background-color: #5ac864;
#   color: #000000;
# }
# #T_f88e7_row0_col1, #T_f88e7_row1_col0, #T_f88e7_row1_col1 {
#   background-color: #fde725;
#   color: #000000;
# }
# #T_f88e7_row2_col0 {
#   background-color: #33638d;
#   color: #f1f1f1;
# }
# #T_f88e7_row2_col1 {
#   background-color: #25858e;
#   color: #f1f1f1;
# }
# #T_f88e7_row3_col0 {
#   background-color: #20928c;
#   color: #f1f1f1;
# }
# #T_f88e7_row3_col1 {
#   background-color: #2d708e;
#   color: #f1f1f1;
# }
# #T_f88e7_row4_col0 {
#   background-color: #3a548c;
#   color: #f1f1f1;
# }
# #T_f88e7_row4_col1 {
#   background-color: #38588c;
#   color: #f1f1f1;
# }
# #T_f88e7_row5_col0 {
#   background-color: #33628d;
#   color: #f1f1f1;
# }
# #T_f88e7_row5_col1 {
#   background-color: #3e4c8a;
#   color: #f1f1f1;
# }
# #T_f88e7_row6_col0 {
#   background-color: #482979;
#   color: #f1f1f1;
# }
# #T_f88e7_row6_col1, #T_f88e7_row7_col1 {
#   background-color: #482173;
# ...

# %% [markdown]
# - Построим диаграмму размаха для сравнения среднего чека в разных районах Москвы:

# %%
# Построим диаграмму размаха
plt.figure(figsize=(12, 4))
ax = sns.boxplot(data=df, 
                 x='middle_avg_bill', 
                 y='district',
                 order=df.groupby('district')['middle_avg_bill'].median().sort_values(ascending=False).index)
plt.xlabel("Средний чек")
plt.ylabel("Район")
plt.suptitle("Средний чек по районам Москвы")
plt.show()

# %% [markdown]
# - Также построим диаграмму плотности, чтобы видеть структуру цен в каждом районе:

# %%
plt.figure(figsize=(12, 4))
ax = sns.kdeplot(data=df, x='middle_avg_bill', hue='district')
plt.xlabel('Средний чек, р.')
plt.ylabel('Плотность')
plt.suptitle("Средний чек по районам Москвы (плотность KDE)")
plt.show()

# %% [markdown]
# <div class="alert alert-warning">
# <b>⚠️ Комментарий ревьюера v1:</b>
# <br>Тут еще можно было бы добавить барплот, где для каждой категории было бы два столбца - со средней и медианной ценой. Это позволило бы сравнить цены внутри округа и округа между собой
# </div>

# %% [markdown]
# <div class="alert alert-info">
# <b>Комментарий студента:</b>
# <br>
# Сделал
# </div>

# %% [markdown]
# Отобразим средние и медианные цены на столбчатой диаграмме:

# %%
# Составной датафрейм для построения диаграммы
df_price_diag = pd.DataFrame(
            {"Среднее": df.groupby('district')['middle_avg_bill'].mean(),
             "Медиана": df.groupby('district')['middle_avg_bill'].median()}).sort_values(by='Медиана')

# Строим столбчатую диаграмму по ЦАО и всей Москве
df_price_diag.plot(
    title="Средние значения и медианы чека по районам",
    kind="barh",
    figsize=(8, 4),
    ylabel="Районы",
    xlabel="Средний чек, р.",
    grid=True
    )

plt.show()

# %% [markdown]
# - На диаграмме размаха видно, что в ЦАО зафиксировано больше высоких значений среднего чека (обозначены как выбросы).
# - В то же время наибольшее количество заведений в ЦАО имеет средний чек менее 2000р., а количество таких заведений значительно больше, чем в других районах, поэтому средний чек в целом по району оказывается на уровне ЗАО.
# - В САО и ВАО среднее сильнее отличается от медианы за счет выбросов (есть средние чеки 10000р. и выше).
# - Наименьшее значение среднего чека - в ЮВАО, СВАО и ЮАО, где находится большое количество этнических заведений, ориентированных на мигрантов.

# %% [markdown]
# # 4. Выводы
#
# В ходе исследования были проанализированы данные о 8406 заведениях общественного питания г. Москвы. Данные включали название, адрес, количество посадочных мест, рейтинг заведения. В отдельном датасете для 48.2% заведений были представлены сведения о ценовой категории и среднем чеке заведений. На этапе предобработки были проанализированы пропуски в данных и сделаны предположения о причинах их появления. Пропуски были заполнены значениями-индикаторами. Записи с аномальными значениями посадочных мест и среднего чека были удалены.
#
# Акцент исследования был сделан на анализе связей между категорией заведения, его вместимостью, местоположением, ценовой политикой и рейтингом. Были изучены распределения всех этих параметров по отдельности и их возможная корреляция.
# - Было установлено, что наиболее распространенными категориями заведений являются кафе, ресторан и кофейня, а наибольшее количество заведений располагается в Центральном административном округе, причем доля ресторанов и баров/пабов в ЦАО больше, чем в других районах.
# - К сетевым принадлежат 38.12% всех заведений, наибольшая доля сетевых заведений среди кофеен, булочных и пиццерий (больше 50%); наименьшая - среди баров/пабов, столовых и кафе.
# - Среднее количество посадочных мест - около 50, а наибольшее их количество в ресторанах, барах, кофейнях и столовых. Нужно отметить, что предоставленные данные о посадочных местах имели низкое качество - в них было 42.9% пропусков; для заведений, расположенных в фудкортах, была указана емкость всего фудкорта, в небольшом количестве присутствовали выбросы (были удалены). Качество данных могло повлиять на достоверность полученных показателей.
# - Исследование рейтингов заведений разных категорий показало, что медианные рейтинги выше у баров/пабов, самые низкие - у кафе, заведений быстрого питания. У остальных категорий заведений - примерно на одном уровне; наибольший диапазон рейтингов - у кафе, заведений быстрого питания, наименьший - у булочных и пиццерий.
# - Анализ корреляции рейтинга с прочими параметрами заведений показал наибольшее значение у корреляции с ценовой категорией, дополнительное исследование показало прямую связь ценовой категории с рейтингом. Однако очевидно, что в данном случае не высокие цены являются причиной более высокого рейтинга, а наоборот, высокое качество заведения и его популярность позволяют держать цены на более высоком уровне.
# - Исследование рейтинга по 15 самым распространенным сетям показало, что наименьший средний рейтинг у ресторанов, наивысший - у булочных и сетей быстрого питания, причем для ресторанов и кофеен, а также для кафе присутствуют рейтинги ниже 3.5, что говорит о неравномерном качестве сетевых заведений этих категорий.
# - Наивысшие медианные значения среднего чека наблюдаются у заведений в ЦАО, ЗАО, СЗАО, причем для ЗАО и ЦАО эти значения равны.
#
# Исходя из результатов анализа, можно предположить, что наиболее перспективным вариантом стало бы открытие бара/паба или ресторана (заведения, которые получают наивысшие медианные рейтинги) в ЦАО, ЗАО или СЗАО (районы с наибольшим значением медианного среднего чека) с количеством посадочных мест 80-86 (медианное значение для заведений этих типов).

# %% [markdown]
# <div class="alert alert-danger">
# <b>❌ Итоговый комментарий ревьюера v1:</b>
# <br>Необходимо поправить:
# <br>- проверить наличие сортировки в каждом графике
# <br>- рассчитать долю сетевых от общего количества заведений
# <br>- изучить взаимосвязь с ценой
#
# <br>После всех внесённых правок не забудь поправить выводы там, где это необходимо
# </div>

# %% [markdown]
# <div class="alert alert-info">
# <b>Комментарий студента:</b>
# <br>
# Все замечания учтены, ошибки исправлены
# </div>
